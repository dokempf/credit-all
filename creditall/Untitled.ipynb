# %%
import json

# %%
data = json.load(open("/home/dominic/scratch/.allcontributorsrc", "r"))

# %%
data["contributors"]
# Out:
# [{'login': 'kentcdodds',
#   'name': 'Kent C. Dodds',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1500684?v=3',
#   'profile': 'https://kentcdodds.com',
#   'contributions': ['question', 'doc', 'review', 'talk']},
#  {'login': 'jfmengels',
#   'name': 'Jeroen Engels',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/3869412?v=3',
#   'profile': 'https://github.com/jfmengels',
#   'contributions': ['doc', 'review', 'tool']},
#  {'login': 'jakebolam',
#   'name': 'Jake Bolam',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/3534236?v=4',
#   'profile': 'https://jakebolam.com',
#   'contributions': ['doc',
#    'tool',
#    'infra',
#    'maintenance',
#    'review',
#    'question']},
#  {'login': 'tbenning',
#   'name': 'Tyler Benning',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/7265547?v=4',
#   'profile': 'https://github.com/tbenning',
#   'contributions': ['maintenance', 'code', 'design']},
#  {'login': 'sinchang',
# ...
